# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
from textblob import TextBlob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# input file path
input_path = "/content/drive/My Drive/Colab Notebooks/preprocessed_output.txt"

# Read the text from the file and remove newline characters
with open(input_path, 'r') as file:
    text = [line.rstrip() for line in file.readlines()]

# Create a DataFrame with the text
result_df = pd.DataFrame({'Text': text})

# Display the DataFrame
print(result_df.head())
# Out:
#                             Text
# 0                 yeah sad liked
# 1            sad hear rest peace
# 2              sad one even care
# 3                       perioddd
# 4  someone hated twitter account

# %%
# function to calculate subjectivity, polarity
def polarity_calc(text):
  try:
    return TextBlob(text).sentiment.polarity
  except:
    return None

# function to give a score with below threhold
def tag_calc(num):
  if num < 0.05:
    return 'Negative'
  elif num > 0.05:
    return 'Positive'
  else:
    return 'Neutral'

# %%
result_df['polarity'] = result_df['Text'].apply(polarity_calc) # took approximately 45 seconds

# %%
result_df['tag'] = result_df['polarity'].apply(tag_calc)

# %%
result_df[:20]
# Out:
#                                                  Text  polarity       tag
# 0                                      yeah sad liked  0.050000  Negative
# 1                                 sad hear rest peace -0.500000  Negative
# 2                                   sad one even care -0.500000  Negative
# 3                                            perioddd  0.000000  Negative
# 4                       someone hated twitter account -0.900000  Negative
# 5   since celebrate graduation post throwback hono...  0.000000  Negative
# 6                                               unite  0.000000  Negative
# 7                                               mr go  0.000000  Negative
# 8   u inaction ineptitude instability caused worst... -0.400000  Negative
# 9   based moment new leaf saharah wackier make sad... -0.181818  Negative
# 10  vilification bill gate disturbing many people ...  0.144444  Positive
# 11               mass unemployment depression sadness  0.000000  Negative
# ...

# %%
result_df.to_csv('/content/drive/My Drive/Colab Notebooks/preprocessed_combined_data_with_textblob_sentiment_analysis.csv', index=False)
